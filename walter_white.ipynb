# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
img= plt.imread('/home/jericho/Pictures/walterwhite.jpg')
plt.imshow(img)

# %%
plt.figure()
img_red=img[:, :, 0]
plt.imshow(img_red,cmap=plt.cm.gray)

# %%
plt.figure()
img_small=img[::29,::29]
plt.imshow(img_small, interpolation='nearest')

plt.show()
