# %%
import numpy as np

# %%
x=np.linspace(0,1,20)

# %%
y=np.cos(x)+0.3*np.random.rand(20)

# %%
p=np.poly1d(np.polyfit(x,y,3))

# %%
t=np.linspace(0,1,200)

# %%
import matplotlib.pyplot as plt
plt.plot(x,y,'o',t,p(t),'-')
# Out:
# [<matplotlib.lines.Line2D at 0x7f420494c198>,
#  <matplotlib.lines.Line2D at 0x7f420494c2e8>]

# %%
x=np.linspace(-1,1,2000)

# %%
y=np.cos(x)+0.3*np.random.rand(2000)

# %%
p=np.polynomial.Chebyshev.fit(x,y,90)

# %%
t=np.linspace(-1,1,200)

# %%
plt.plot(x,y,'g.')
plt.plot(t,p(t),'k-',lw=3)

# %%
plt.figure()
img=plt.imread('/home/guest/Downloads/Robert_Downey_Jr_avp_Iron_Man_3_Paris.jpg')
plt.imshow(img)

# %%
plt.savefig('plot.jpg')

# %%
plt.figure()
img_red=img[:, :, 0]
plt.imshow(img_red,cmap=plt.cm.gray)

# %%
plt.figure()
img_small=img[::15,::15]
plt.imshow(img_small, interpolation='nearest')

plt.show()
