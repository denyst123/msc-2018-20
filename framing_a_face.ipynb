# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
from scipy import misc

# %%
face=misc.face(gray=True)

# %%
plt.imshow(face)

# %%
plt.imshow(face,cmap=plt.cm.gray)

# %%
crop_face=face[100:-100, 100:-100]

# %%
sy, sx = face.shape

# %%
y, x = np.ogrid[0:sy, 0:sx]

# %%
y.shape,x.shape
# Out:
# ((768, 1), (1, 1024))

# %%
centrex, centrey = (600,300)

# %%
mask=((y-centrey)**2+(x-centrex)**2)>230**2

# %%
face[mask]=0

# %%
plt.imshow(face)

# %%
plt.show()
